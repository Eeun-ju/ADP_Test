# %% [markdown]
# <a href="https://colab.research.google.com/github/Eeun-ju/ADP_Test/blob/main/ADP_%EA%B8%B0%EC%B6%9C%EB%AC%B8%EC%A0%9C_230827.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/ADPclass/ADP_book_ver01/main/data/student_data.csv')

# %%
## read_csv 한글깨짐이 생기면, engine = 'python' // encoding = 'utf-8'
## 라이브러리 함수 전체 출력  dir(pd) dir(np)

# %%
data
# Out:
#     school sex paid activities  famrel  freetime  goout  Dalc  Walc  health  \
# 0       GP   F   no         no     4.0       3.0    4.0   1.0   1.0     3.0
# 1       GP   F   no         no     5.0       3.0    3.0   1.0   1.0     3.0
# 2       GP   F  yes         no     4.0       3.0    2.0   2.0   3.0     3.0
# 3       GP   F  yes        yes     3.0       2.0    2.0   1.0   1.0     5.0
# 4       GP   F  yes         no     4.0       3.0    2.0   1.0   2.0     5.0
# ..     ...  ..  ...        ...     ...       ...    ...   ...   ...     ...
# 390     MS   M  yes         no     5.0       5.0    4.0   4.0   5.0     4.0
# 391     MS   M   no         no     2.0       4.0    5.0   3.0   4.0     2.0
# 392     MS   M   no         no     5.0       5.0    3.0   3.0   3.0     3.0
# 393     MS   M   no         no     4.0       4.0    1.0   3.0   4.0     5.0
# 394     MS   M   no         no     3.0       2.0    3.0   3.0   3.0     5.0
#
#      absences  grade  G1  G2
# ...

# %%
## EDA(시각화포함)

# %%
data.head()
# Out:
#   school sex paid activities  famrel  freetime  goout  Dalc  Walc  health  \
# 0     GP   F   no         no     4.0       3.0    4.0   1.0   1.0     3.0
# 1     GP   F   no         no     5.0       3.0    3.0   1.0   1.0     3.0
# 2     GP   F  yes         no     4.0       3.0    2.0   2.0   3.0     3.0
# 3     GP   F  yes        yes     3.0       2.0    2.0   1.0   1.0     5.0
# 4     GP   F  yes         no     4.0       3.0    2.0   1.0   2.0     5.0
#
#    absences  grade  G1  G2
# 0       6.0      6   5   6
# 1       4.0      5   5   5
# 2      10.0      8   7   8
# 3       2.0     15  15  14
# 4       4.0      9   6  10

# %%
data.shape
# Out:
# (395, 14)

# %%
data.describe(include = 'all') ## 전체 컬럼대상 집계
# Out:
#        school  sex paid activities      famrel    freetime       goout  \
# count     395  395  395        395  394.000000  393.000000  392.000000
# unique      2    2    2          2         NaN         NaN         NaN
# top        GP    F   no        yes         NaN         NaN         NaN
# freq      349  208  214        201         NaN         NaN         NaN
# mean      NaN  NaN  NaN        NaN    3.944162    3.239186    3.114796
# std       NaN  NaN  NaN        NaN    0.897794    0.994265    1.112397
# min       NaN  NaN  NaN        NaN    1.000000    1.000000    1.000000
# 25%       NaN  NaN  NaN        NaN    4.000000    3.000000    2.000000
# 50%       NaN  NaN  NaN        NaN    4.000000    3.000000    3.000000
# 75%       NaN  NaN  NaN        NaN    5.000000    4.000000    4.000000
# max       NaN  NaN  NaN        NaN    5.000000    5.000000    5.000000
#
#               Dalc        Walc      health    absences       grade  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.bar()
